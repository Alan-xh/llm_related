# %% [markdown]
# # 教程指南
#
# 本教程**需要一个API密钥**才能进行交互。如果您没有API密钥，可以通过[Anthropic Console](https://console.anthropic.com/)注册获取，或者查看我们的[静态教程答案密钥](https://docs.google.com/spreadsheets/u/0/d/1jIxjzUWG-6xBVIa2ay6yDpLyeuOh_hR_ZB75a47KX_E/edit)。

# %% [markdown]
# ## 如何开始
#
# 1. 将此存储库克隆到您的本地机器。
#
# 2. 通过运行以下命令安装所需的依赖项：

# %%
# !pip install anthropic

# %% [markdown]
# 3. 设置您的API密钥和模型名称。将`"your_api_key_here"`替换为您实际的Anthropic API密钥。

# %%
API_KEY = "your_api_key_here"
MODEL_NAME = "claude-3-haiku-20240307"

# 将 API_KEY 和 MODEL_NAME 变量存储在 IPython 存储中，以便在笔记本之间使用
# %store API_KEY
# %store MODEL_NAME

# %% [markdown]
# 4. 按顺序运行笔记本中的单元格，并按照提供的说明进行操作。

# %% [markdown]
# ---
#
# ## 使用说明与提示 💡
#
# - 本课程使用 Claude 3 Haiku，温度设置为0。我们将在课程后续讨论更多关于温度的内容。目前，只需了解这些设置会产生更确定的结果。本课程中的所有提示工程技术也适用于上一代遗留Claude模型，例如Claude 2和Claude Instant 1.2。
#
# - 您可以使用`Shift + Enter`执行单元格并移动到下一个单元格。
#
# - 当您到达教程页面底部时，导航到文件夹中的下一个编号文件，或者如果您已完成该章节文件中的内容，则导航到下一个编号文件夹。
#
# ### Anthropic SDK 与 Messages API
# 我们将在本教程中全程使用 [Anthropic Python SDK](https://docs.anthropic.com/claude/reference/client-sdks) 和 [Messages API](https://docs.anthropic.com/claude/reference/messages_post)。
#
# 以下是运行提示的示例。首先，我们创建`get_completion`，这是一个辅助函数，用于向Claude发送提示并返回Claude生成的响应。现在运行该单元格。

# %%
import anthropic

client = anthropic.Anthropic(api_key=API_KEY)

def get_completion(prompt: str):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )
    return message.content[0].text

# %% [markdown]
# 现在我们将为Claude编写一个示例提示，并通过运行我们的`get_completion`辅助函数打印Claude的输出。运行下面的单元格将在其下方打印Claude的响应。
#
# 您可以自由尝试修改提示字符串，以从Claude获得不同的响应。

# %%
# 提示
prompt = "Hello, Claude!"

# 获取Claude的响应
print(get_completion(prompt))

# %% [markdown]
# 之前定义的`API_KEY`和`MODEL_NAME`变量将在整个教程中使用。请确保从上到下按顺序运行每个教程页面的单元格。
